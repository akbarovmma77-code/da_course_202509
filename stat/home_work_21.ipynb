# %%
import math as mt

# %% [markdown]
# №1

# %%
pass_num = 5
quan = 10
print(10**5) #количество возможных вариантов
# Out:
# 100000

# %% [markdown]
# №2

# %%
book_hp = 7
count_hp = mt.factorial(7)
print(count_hp) #количество вариантов поставить книги
# Out:
# 5040

# %% [markdown]
# №3

# %%
dots = 9
line1 = 2
result = mt.factorial(9)/(mt.factorial(2)*mt.factorial(9-2))
print(result) #36 можно провести линий
# Out:
# 36.0

# %% [markdown]
# №4

# %%
#не смог
